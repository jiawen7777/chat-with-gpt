# %%
import openai


openai.api_key = "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"
# A ChatCompletion request
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role': 'user', 'content': "What's 1+1+1?"}
    ],
    temperature=0,
    stream=True  # this time, we set stream=True
)

for chunk in response:
    print(chunk)
# Out:
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "",
#         "role": "assistant"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "1"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "+"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "1"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "+"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "1"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": " equals"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": " "
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "3"
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {
#         "content": "."
#       },
#       "finish_reason": null,
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }
# {
#   "choices": [
#     {
#       "delta": {},
#       "finish_reason": "stop",
#       "index": 0
#     }
#   ],
#   "created": 1699517026,
#   "id": "chatcmpl-8IuIsZfmGdgwnKkjRniKxmjiPjfgu",
#   "model": "gpt-3.5-turbo-0613",
#   "object": "chat.completion.chunk"
# }

# %%
def get_openai_generator(prompt: str):
    openai_stream = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.0,
        stream=True,
    )

    for event in openai_stream:
        if "content" in event["choices"][0].delta:
            current_response = event["choices"][0].delta.content
            yield current_response

# %%
openai_generator = get_openai_generator("what's the answer to 1+1 = 2? Do it step by step")
for chunk in openai_generator:
    print(chunk, end='', flush=True)
# Out:
# To solve 1 + 1 step by step, we can follow these steps:
#
# Step 1: Start with the first number, which is 1.
# Step 2: Add the second number, which is also 1, to the first number.
# Step 3: 1 + 1 equals 2.
#
# Therefore, the answer to 1 + 1 is 2.

# %%
import requests

url = "http://localhost:8000/api/chat/stream"

with requests.get(url, stream=True) as r:
    for chunk in r.iter_content(None, decode_unicode=True):
        if chunk:
            print(chunk, end='', flush=True)
# Out:
# {"data": "" }
#
# {"data": "Hello" }
#
# {"data": "!" }
#
# {"data": " The" }
#
# {"data": " sum" }
#
# {"data": " of" }
#
# {"data": " " }
#
# {"data": "1" }
#
# {"data": " +" }
#
# {"data": " " }
#
# {"data": "1" }
#
# {"data": " is" }
#
# {"data": " " }
#
# {"data": "2" }
#
# {"data": "." }
